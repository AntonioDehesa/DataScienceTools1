# %% [markdown]
# # Pandas DataFrame for storing tweet feed (total 12 points)
#
# Creating the following date frame for storing tweets:
#
# - **climate_feed_df** DataFrame for storing tweets
# - **retweeted_status_df** for storing original tweets

# %%
import pandas as pd
import numpy as np
import nltk
import re
import requests
from bs4 import BeautifulSoup as bsp
from datetime import datetime
import ast

# %% [markdown]
# The pickle files retweeted_status_df.pkl and climate_feed.pkl should be in the same folder as this notebook.
# If needed, they can also be downloaded by uncommenting the commands below.  There are csv files of these posted on 2DU under the files section if you are unable to read the pkl files.

# %%
#!wget https://github.com/psnegi/data_science_tools1/raw/master/hws/retweeted_status_df.pkl

# %%
#!wget https://github.com/psnegi/data_science_tools1/raw/master/hws/climate_feed.pkl

# %% [markdown]
# <font color= "red">Click on these links if the above downloads fail. </font>
#
#
# https://github.com/psnegi/data_science_tools1/raw/master/hws/climate_feed.pkl
#
# https://github.com/psnegi/data_science_tools1/raw/master/hws/retweeted_status_df.pkl
#
# Keep these pickle files in the same directory as the notebook

# %%
retweeted_status_df = pd.read_pickle("./retweeted_status_df.pkl")

# %%
retweeted_status_df
# Out:
#       contributors coordinates                      created_at  \
# 0              NaN         NaN                             NaN
# 1              NaN        None  Sat Feb 09 20:27:45 +0000 2019
# 2              NaN        None  Sat Feb 09 23:56:18 +0000 2019
# 3              NaN        None  Sat Feb 09 23:34:27 +0000 2019
# 4              NaN        None  Sat Feb 09 19:07:56 +0000 2019
# ...            ...         ...                             ...
# 9994           NaN        None  Sat Feb 09 20:56:39 +0000 2019
# 9995           NaN        None  Thu Feb 07 20:27:55 +0000 2019
# 9996           NaN        None  Sat Feb 09 18:33:00 +0000 2019
# 9997           NaN        None  Fri Feb 08 22:15:50 +0000 2019
# 9998           NaN        None  Sat Feb 09 20:41:00 +0000 2019
#
#                                                entities extended_entities  \
# 0                                                   NaN               NaN
# 1     {'hashtags': [], 'user_mentions': [], 'urls': ...               NaN
# 2     {'hashtags': [], 'user_mentions': [], 'urls': ...               NaN
# 3     {'hashtags': [], 'user_mentions': [], 'urls': ...               NaN
# 4     {'hashtags': [], 'user_mentions': [], 'urls': ...               NaN
# ...                                                 ...               ...
# 9994  {'hashtags': [], 'user_mentions': [], 'urls': ...               NaN
# 9995  {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 9996  {'hashtags': [], 'user_mentions': [], 'urls': ...               NaN
# 9997  {'hashtags': [], 'user_mentions': [], 'urls': ...               NaN
# 9998  {'hashtags': [], 'user_mentions': [], 'urls': ...               NaN
#
#       favorite_count favorited   geo            id               id_str  ...  \
# 0                NaN       NaN   NaN           NaN                  NaN  ...
# 1               99.0     False  None  1.094332e+18  1094332044052549633  ...
# 2                6.0     False  None  1.094385e+18  1094384528267902977  ...
# 3              190.0     False  None  1.094379e+18  1094379028608438272  ...
# 4             2905.0     False  None  1.094312e+18  1094311957669265408  ...
# ...              ...       ...   ...           ...                  ...  ...
# 9994             1.0     False  None  1.094339e+18  1094339317324017665  ...
# 9995          3491.0     False  None  1.093607e+18  1093607309606076416  ...
# 9996         12586.0     False  None  1.094303e+18  1094303164805799936  ...
# 9997          4249.0     False  None  1.093997e+18  1093996855111966720  ...
# 9998           166.0     False  None  1.094335e+18  1094335377194799104  ...
#
#                                           quoted_status  quoted_status_id  \
# 0                                                   NaN               NaN
# 1                                                   NaN               NaN
# 2     {'favorited': False, 'favorite_count': 2642, '...      1.093999e+18
# 3     {'favorited': False, 'favorite_count': 220, 'i...      1.093932e+18
# 4                                                   NaN               NaN
# ...                                                 ...               ...
# 9994                                                NaN               NaN
# 9995                                                NaN               NaN
# 9996                                                NaN               NaN
# 9997  {'favorited': False, 'favorite_count': 551, 'i...      1.093893e+18
# 9998                                                NaN               NaN
#
#      quoted_status_id_str  retweet_count retweeted scopes  \
# 0                     NaN            NaN       NaN    NaN
# 1                     NaN           81.0     False    NaN
# 2     1093998640392220673            5.0     False    NaN
# 3     1093931686998487040           31.0     False    NaN
# 4                     NaN          599.0     False    NaN
# ...                   ...            ...       ...    ...
# 9994                  NaN            1.0     False    NaN
# 9995                  NaN          482.0     False    NaN
# 9996                  NaN         2801.0     False    NaN
# 9997  1093893115633647616          642.0     False    NaN
# 9998                  NaN           79.0     False    NaN
#
#                                                  source  \
# 0                                                   NaN
# 1     <a href="http://twitter.com" rel="nofollow">Tw...
# 2     <a href="http://twitter.com/download/android" ...
# 3     <a href="http://twitter.com/download/android" ...
# 4     <a href="http://twitter.com/download/iphone" r...
# ...                                                 ...
# 9994  <a href="http://twitter.com/download/android" ...
# 9995  <a href="http://twitter.com/download/android" ...
# 9996  <a href="https://about.twitter.com/products/tw...
# 9997  <a href="https://mobile.twitter.com" rel="nofo...
# 9998  <a href="https://buffer.com" rel="nofollow">Bu...
#
#                                                    text truncated  \
# 0                                                   NaN       NaN
# 1     The National Party declares war on the Glouces...      True
# 2     This is the same idiot who thought\nThe southe...     False
# 3     Communism is Fascism. Fighting Climate Change ...      True
# 4     Unmitigated climate change would literally des...      True
# ...                                                 ...       ...
# 9994  72% of Americans are 'very worried' about clim...     False
# 9995  @JFaurall @MgBenchjeweler @SpeakerPelosi Calif...      True
# 9996  President Trump believes we should listen to f...      True
# 9997  Wait til he hears how much climate change is g...     False
# 9998       Blue marble no more? https://t.co/hFLndZsiBB     False
#
#                                                    user
# 0                                                   NaN
# 1     {'default_profile': False, 'protected': False,...
# 2     {'default_profile': False, 'protected': False,...
# 3     {'default_profile': False, 'protected': False,...
# 4     {'default_profile': True, 'protected': False, ...
# ...                                                 ...
# 9994  {'default_profile': True, 'protected': False, ...
# 9995  {'default_profile': True, 'protected': False, ...
# 9996  {'default_profile': False, 'protected': False,...
# 9997  {'default_profile': False, 'protected': False,...
# 9998  {'default_profile': False, 'protected': False,...
#
# [9999 rows x 30 columns]

# %%
#climate_feed_df.to_pickle("./climate_feed.pkl")
climate_feed_df = pd.read_pickle("./climate_feed.pkl")

# %%
climate_feed_df
# Out:
#      contributors coordinates                      created_at  \
# 0            None        None  Sun Feb 10 00:17:31 +0000 2019
# 1            None        None  Sun Feb 10 00:17:30 +0000 2019
# 2            None        None  Sun Feb 10 00:17:26 +0000 2019
# 3            None        None  Sun Feb 10 00:17:24 +0000 2019
# 4            None        None  Sun Feb 10 00:17:23 +0000 2019
# ...           ...         ...                             ...
# 9994         None        None  Sat Feb 09 20:57:54 +0000 2019
# 9995         None        None  Sat Feb 09 20:57:54 +0000 2019
# 9996         None        None  Sat Feb 09 20:57:53 +0000 2019
# 9997         None        None  Sat Feb 09 20:57:51 +0000 2019
# 9998         None        None  Sat Feb 09 20:57:51 +0000 2019
#
#                                                entities extended_entities  \
# 0     {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 1     {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 2     {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 3     {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 4     {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# ...                                                 ...               ...
# 9994  {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 9995  {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 9996  {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 9997  {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 9998  {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
#
#      favorite_count favorited   geo                   id               id_str  \
# 0                 0     False  None  1094389867499405313  1094389867499405313
# 1                 0     False  None  1094389862193455105  1094389862193455105
# 2                 0     False  None  1094389844078485506  1094389844078485506
# 3                 0     False  None  1094389837522599936  1094389837522599936
# 4                 0     False  None  1094389831419994112  1094389831419994112
# ...             ...       ...   ...                  ...                  ...
# 9994              0     False  None  1094339630500012033  1094339630500012033
# 9995              0     False  None  1094339629107400704  1094339629107400704
# 9996              0     False  None  1094339627316641794  1094339627316641794
# 9997              0     False  None  1094339619569557504  1094339619569557504
# 9998              0     False  None  1094339617581481984  1094339617581481984
#
#       ... quoted_status     quoted_status_id quoted_status_id_str  \
# 0     ...           NaN                  NaN                  NaN
# 1     ...           NaN                  NaN                  NaN
# 2     ...           NaN  1093998640392220673  1093998640392220673
# 3     ...           NaN  1093931686998487040  1093931686998487040
# 4     ...           NaN                  NaN                  NaN
# ...   ...           ...                  ...                  ...
# 9994  ...           NaN                  NaN                  NaN
# 9995  ...           NaN                  NaN                  NaN
# 9996  ...           NaN                  NaN                  NaN
# 9997  ...           NaN  1093893115633647616  1093893115633647616
# 9998  ...           NaN                  NaN                  NaN
#
#      retweet_count retweeted retweeted_status  \
# 0                0     False              NaN
# 1               81     False     1.094332e+18
# 2                5     False     1.094385e+18
# 3               31     False     1.094379e+18
# 4              599     False     1.094312e+18
# ...            ...       ...              ...
# 9994             1     False     1.094339e+18
# 9995           482     False     1.093607e+18
# 9996          2801     False     1.094303e+18
# 9997           642     False     1.093997e+18
# 9998            79     False     1.094335e+18
#
#                                                  source  \
# 0     <a href="http://twitter.com" rel="nofollow">Tw...
# 1     <a href="http://tapbots.com/tweetbot" rel="nof...
# 2     <a href="https://mobile.twitter.com" rel="nofo...
# 3     <a href="http://twitter.com" rel="nofollow">Tw...
# 4     <a href="http://twitter.com/download/android" ...
# ...                                                 ...
# 9994  <a href="http://twitter.com/download/android" ...
# 9995  <a href="http://twitter.com/download/iphone" r...
# 9996  <a href="http://twitter.com/download/android" ...
# 9997  <a href="http://twitter.com/download/iphone" r...
# 9998  <a href="http://twitter.com" rel="nofollow">Tw...
#
#                                                    text truncated  \
# 0     .@SteveKingIA says he's unsure about the scien...      True
# 1     RT @RobOakeshott1: The National Party declares...     False
# 2     RT @emilia_suze: This is the same idiot who th...     False
# 3     RT @PrettyBadLefty: Communism is Fascism. Figh...     False
# 4     RT @kenklippenstein: Unmitigated climate chang...     False
# ...                                                 ...       ...
# 9994  RT @fromhello2hello: 72% of Americans are 'ver...     False
# 9995  RT @stuntdaddy_42: @JFaurall @MgBenchjeweler @...     False
# 9996  RT @SenSanders: President Trump believes we sh...     False
# 9997  RT @KateAronoff: Wait til he hears how much cl...     False
# 9998  RT @GeorgeTakei: Blue marble no more? https://...     False
#
#                   user_id
# 0                31476142
# 1               996782298
# 2                45333453
# 3     1020067726532829185
# 4                19889325
# ...                   ...
# 9994   888112320097918976
# 9995           3324836714
# 9996           1487109794
# 9997           4737089913
# 9998             19444003
#
# [9999 rows x 30 columns]

# %% [markdown]
# Here are dtypes for climate_feed_df. We'll work with only
# - entities to extract hashtags
# - retweeted_status in case we need to extract original full tweet
# - truncated
# - text: tweet text
# - created_at
# - user_id
#
# Some of them have wrong datatypes.

# %%
climate_feed_df.dtypes
# Out:
# contributors                  object
# coordinates                   object
# created_at                    object
# entities                      object
# extended_entities             object
# favorite_count                object
# favorited                     object
# geo                           object
# id                            object
# id_str                        object
# in_reply_to_screen_name       object
# in_reply_to_status_id         object
# in_reply_to_status_id_str     object
# in_reply_to_user_id           object
# in_reply_to_user_id_str       object
# is_quote_status               object
# lang                          object
# metadata                      object
# place                         object
# possibly_sensitive            object
# quoted_status                 object
# quoted_status_id              object
# quoted_status_id_str          object
# retweet_count                 object
# retweeted                     object
# retweeted_status             float64
# source                        object
# text                          object
# truncated                     object
# user_id                        int64
# dtype: object

# %% [markdown]
# # Q1 (0.5 point) Replace None with nan in climate_feed_df. Also display some random rows.

# %%
# write code here
climate_feed_df.replace("None", np.nan)
climate_feed_df.sample(10)
# Out:
#      contributors coordinates                      created_at  \
# 84           None        None  Sun Feb 10 00:15:28 +0000 2019
# 432          None        None  Sun Feb 10 00:08:36 +0000 2019
# 3363         None        None  Sat Feb 09 23:13:00 +0000 2019
# 3430         None        None  Sat Feb 09 23:11:26 +0000 2019
# 9258         None        None  Sat Feb 09 21:11:36 +0000 2019
# 1240         None        None  Sat Feb 09 23:53:25 +0000 2019
# 7713         None        None  Sat Feb 09 21:42:29 +0000 2019
# 8982         None        None  Sat Feb 09 21:16:37 +0000 2019
# 5621         None        None  Sat Feb 09 22:24:21 +0000 2019
# 2165         None        None  Sat Feb 09 23:36:09 +0000 2019
#
#                                                entities extended_entities  \
# 84    {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 432   {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 3363  {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 3430  {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 9258  {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 1240  {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 7713  {'hashtags': [{'indices': [88, 101], 'text': '...               NaN
# 8982  {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 5621  {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 2165  {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
#
#      favorite_count favorited   geo                   id               id_str  \
# 84                0     False  None  1094389351407108096  1094389351407108096
# 432               0     False  None  1094387620342317056  1094387620342317056
# 3363              0     False  None  1094373628638945280  1094373628638945280
# 3430              0     False  None  1094373237130231808  1094373237130231808
# 9258              0     False  None  1094343076565245952  1094343076565245952
# 1240              0     False  None  1094383802053386240  1094383802053386240
# 7713              0     False  None  1094350851077009409  1094350851077009409
# 8982              0     False  None  1094344339667341318  1094344339667341318
# 5621              0     False  None  1094361388330278912  1094361388330278912
# 2165              0     False  None  1094379456486166528  1094379456486166528
#
#       ... quoted_status     quoted_status_id quoted_status_id_str  \
# 84    ...           NaN                  NaN                  NaN
# 432   ...           NaN                  NaN                  NaN
# 3363  ...           NaN                  NaN                  NaN
# 3430  ...           NaN                  NaN                  NaN
# 9258  ...           NaN                  NaN                  NaN
# 1240  ...           NaN  1090439773754478592  1090439773754478592
# 7713  ...           NaN                  NaN                  NaN
# 8982  ...           NaN                  NaN                  NaN
# 5621  ...           NaN                  NaN                  NaN
# 2165  ...           NaN                  NaN                  NaN
#
#      retweet_count retweeted retweeted_status  \
# 84            2794     False     1.094303e+18
# 432           4006     False     1.094212e+18
# 3363            11     False     1.094086e+18
# 3430           350     False     1.094335e+18
# 9258            28     False     1.094322e+18
# 1240           765     False     1.090722e+18
# 7713           391     False     1.094018e+18
# 8982             4     False     1.094342e+18
# 5621          7912     False     1.093905e+18
# 2165           350     False     1.094335e+18
#
#                                                  source  \
# 84    <a href="http://twitter.com/download/iphone" r...
# 432   <a href="https://mobile.twitter.com" rel="nofo...
# 3363  <a href="https://about.twitter.com/products/tw...
# 3430  <a href="http://twitter.com/download/iphone" r...
# 9258  <a href="http://twitter.com/download/iphone" r...
# 1240  <a href="http://twitter.com/download/iphone" r...
# 7713  <a href="http://twitter.com/download/iphone" r...
# 8982  <a href="http://twitter.com/download/iphone" r...
# 5621  <a href="http://twitter.com/download/iphone" r...
# 2165  <a href="http://twitter.com" rel="nofollow">Tw...
#
#                                                    text truncated  \
# 84    RT @SenSanders: President Trump believes we sh...     False
# 432   RT @marklevinshow: The insane Democrat Left.  ...     False
# 3363  RT @greensjeremy: Johnsen's attitude shows tha...     False
# 3430  RT @SiddonsDan: “Does God’s creation not inclu...     False
# 9258  RT @Morse4America: With the highest fire risk ...     False
# 1240  RT @suntzufuntzu: Kamala Harris unveils her cl...     False
# 7713  RT @SenBlumenthal: Climate change is an existe...     False
# 8982  RT @maxphillips: This goose attacks the judge ...     False
# 5621  RT @brianschatz: I’m not a socialist. But I be...     False
# 2165  RT @SiddonsDan: “Does God’s creation not inclu...     False
#
#                   user_id
# 84    1089666723459067904
# 432             175170072
# 3363   778496715548536832
# 3430   824322536204865537
# 9258   797331951258451968
# 1240   879162384086056960
# 7713            801155018
# 8982             91676348
# 5621            920116788
# 2165            103466695
#
# [10 rows x 30 columns]

# %% [markdown]
# Working with only selected attributes.

# %%
climate_feed_df = climate_feed_df[['created_at', 'entities','retweeted_status', 'truncated', 'user_id', 'text' ]].copy()

# %%
climate_feed_df.sample(10)
# Out:
#                           created_at  \
# 9959  Sat Feb 09 20:58:38 +0000 2019
# 7163  Sat Feb 09 21:52:33 +0000 2019
# 5369  Sat Feb 09 22:28:43 +0000 2019
# 7486  Sat Feb 09 21:46:47 +0000 2019
# 5022  Sat Feb 09 22:35:46 +0000 2019
# 2394  Sat Feb 09 23:32:00 +0000 2019
# 2688  Sat Feb 09 23:26:41 +0000 2019
# 9257  Sat Feb 09 21:11:36 +0000 2019
# 9927  Sat Feb 09 20:59:05 +0000 2019
# 6535  Sat Feb 09 22:05:22 +0000 2019
#
#                                                entities  retweeted_status  \
# 9959  {'hashtags': [], 'user_mentions': [{'id_str': ...      1.094312e+18
# 7163  {'hashtags': [], 'user_mentions': [{'id_str': ...      1.094300e+18
# 5369  {'hashtags': [], 'user_mentions': [{'id_str': ...      1.094303e+18
# 7486  {'hashtags': [], 'user_mentions': [], 'urls': ...               NaN
# 5022  {'hashtags': [{'indices': [88, 101], 'text': '...      1.094018e+18
# 2394  {'hashtags': [], 'user_mentions': [], 'urls': ...               NaN
# 2688  {'hashtags': [], 'user_mentions': [{'id_str': ...      1.094256e+18
# 9257  {'hashtags': [], 'user_mentions': [{'id_str': ...      1.094312e+18
# 9927  {'hashtags': [], 'user_mentions': [], 'urls': ...               NaN
# 6535  {'hashtags': [], 'user_mentions': [{'id_str': ...      1.094299e+18
#
#      truncated              user_id  \
# 9959     False  1004494460657401858
# 7163     False  1062132627266768896
# 5369     False  1010711915000225795
# 7486      True            589841885
# 5022     False             24606967
# 2394     False             41287144
# 2688     False   756563102359924736
# 9257     False           3237743390
# 9927      True             14686744
# 6535     False            372482470
#
#                                                    text
# 9959  RT @kenklippenstein: Unmitigated climate chang...
# 7163  RT @BusyElves: Sen. Lindsey Graham wants Congr...
# 5369  RT @wesyang: This LRB piece from 2014 made a v...
# 7486  “Those who should be leading us out of this cr...
# 5022  RT @SenBlumenthal: Climate change is an existe...
# 2394  With the Green New Deal, Democrats Present a R...
# 2688  RT @FaithGoldy: PPC candidate banned from clim...
# 9257  RT @kenklippenstein: Unmitigated climate chang...
# 9927  "This experience made her comfortable challeng...
# 6535  RT @ArielAnaliza: Masacre de 56 millones de in...

# %% [markdown]
# # Q2 (0.5 point) convert
# - created_at to date time type
# - truncated to bool type.

# %%
# write code here
climate_feed_df["truncated"] = climate_feed_df["truncated"].map({'True': True, 'False': False}) 
date_format = '%a %b %d %H:%M:%S %z %Y'
climate_feed_df["created_at"] = pd.to_datetime(climate_feed_df["created_at"],format=date_format)

# %% [markdown]
# Checking datatype again

# %%
climate_feed_df.dtypes
# Out:
# created_at          datetime64[ns, UTC]
# entities                         object
# retweeted_status                float64
# truncated                          bool
# user_id                           int64
# text                             object
# dtype: object

# %% [markdown]
# # Q3(1 point) In climate_feed_df, calculate the number of NAN values in various columns

# %%
# write code here
print("NaN values in:")
climate_feed_df.isna().sum()
# Out:
# NaN values in:
# created_at             0
# entities               0
# retweeted_status    2690
# truncated              0
# user_id                0
# text                   0
# dtype: int64

# %% [markdown]
# We'll use **ast** module to parse string to python dictionary

# %% [markdown]
# # Q4(3 points) Using *ast* module  convert entities to python dictionary. This dictionary should contain hashtags and user_mentions
#  - Create a column named hashtags. Values in this columns should be comma separated values of **text** attribute in **hashtags**  value.
#  - Create a column named user_mentions. Values in this columns should be command separated values of **name** attribute in **user_mentions** values.

# %%
# write code here
def get_hashtag(main_dict):
    try:
        d = ast.literal_eval(main_dict)
        all_hashtags = []
        for h in d["hashtags"]:
            all_hashtags.append(h["text"])
        text = ",".join(all_hashtags)
    except:
        text = np.nan
    return text

def get_name(main_dict):
    try:
        d = ast.literal_eval(main_dict)
        all_users = []
        for u in d["user_mentions"]:
            all_users.append(u["name"])
        name = ",".join(all_users)
    except:
        name = np.nan
    return name

climate_feed_df["hashtags"] = climate_feed_df["entities"].apply(get_hashtag)
climate_feed_df["user_mentions"] = climate_feed_df["entities"].apply(get_name)
climate_feed_df[~climate_feed_df["text"].isna()].sample(100)
# Out:
#                     created_at  \
# 5196 2019-02-09 22:32:17+00:00
# 9382 2019-02-09 21:09:40+00:00
# 254  2019-02-10 00:12:03+00:00
# 4795 2019-02-09 22:40:47+00:00
# 4592 2019-02-09 22:46:00+00:00
# ...                        ...
# 6491 2019-02-09 22:06:15+00:00
# 4827 2019-02-09 22:40:05+00:00
# 210  2019-02-10 00:12:53+00:00
# 752  2019-02-10 00:02:13+00:00
# 7365 2019-02-09 21:48:53+00:00
#
#                                                entities  retweeted_status  \
# 5196  {'hashtags': [], 'user_mentions': [{'id_str': ...      1.093895e+18
# 9382  {'hashtags': [], 'user_mentions': [{'id_str': ...      1.094212e+18
# 254   {'hashtags': [], 'user_mentions': [{'id_str': ...      1.094381e+18
# 4795  {'hashtags': [], 'user_mentions': [], 'urls': ...               NaN
# 4592  {'hashtags': [], 'user_mentions': [], 'urls': ...               NaN
# ...                                                 ...               ...
# 6491  {'hashtags': [{'indices': [39, 54], 'text': 'P...      1.094102e+18
# 4827  {'hashtags': [], 'user_mentions': [{'id_str': ...      1.094363e+18
# 210   {'hashtags': [], 'user_mentions': [{'id_str': ...      1.094379e+18
# 752   {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 7365  {'hashtags': [], 'user_mentions': [{'id_str': ...      1.094312e+18
#
#       truncated              user_id  \
# 5196      False             86397925
# 9382      False   992881513573298178
# 254       False           1397469289
# 4795      False   991235382879518720
# 4592      False           4724931868
# ...         ...                  ...
# 6491      False  1093869831282196486
# 4827      False            527675712
# 210       False   750476845175365634
# 752        True   771446113471717377
# 7365      False             22168487
#
#                                                    text        hashtags  \
# 5196  RT @guardian: Global school strikes over clima...
# 9382  RT @marklevinshow: The insane Democrat Left.  ...
# 254   RT @TDPattillo: @realDonaldTrump Donald Trump ...
# 4795  Electric vehicles are perfect solution in figh...
# 4592  Carl Sagan told Everyone, Climate Change is Se...
# ...                                                 ...             ...
# 6491  RT @ImranKhanPTI: We are launching our #Plant4...  Plant4Pakistan
# 4827  RT @ByPeterCoutu: Virginia wants more action o...
# 210   RT @kerwinftw: @DavidWohl @realDonaldTrump Hey...
# 752   @AllanMargolin @ClimateCentral @EaterSouls @so...
# 7365  RT @kenklippenstein: Unmitigated climate chang...
#
#                                           user_mentions
# 5196                                       The Guardian
# 9382                                      Mark R. Levin
# 254                                 TDP,Donald J. Trump
# 4795
# 4592
# ...                                                 ...
# 6491                                         Imran Khan
# 4827                                        Peter Coutu
# 210              Noah Kerwin,David Wohl,Donald J. Trump
# 752   Allan Margolin,Climate Central,Eater of Souls ...
# 7365                                   Ken Klippenstein
#
# [100 rows x 8 columns]

# %% [markdown]
# # Cleaning tweets
#
# Let's see some random tweets

# %%
tweet_length = 280
pd.set_option('max_colwidth', 2*tweet_length)
climate_feed_df['text'].sample(100)
# Out:
# 9022      "Meanwhile climate change threatens humanity and most forms of life with extinction. All we’ve awaited throughout t… https://t.co/FuKN8UKFt2
# 1740      RT @EugeneMirman: “It feels like no one ever talks about the positive environmental impact Hitler’s vegetarianism had on mitigating man-mad…
# 1506                   A Huge Climate Change Movement Led By Teenage Girls Is Sweeping Europe. And It’s Coming To The US Next. https://t.co/MNkET6PcNW
# 9035      RT @kenklippenstein: Unmitigated climate change would literally destroy civilization but doing something about it might increase the defici…
# 7090       TheEconomist" "If innovators, investors, the courts and corporate self-interest cannot curb fossil fuels, then the… https://t.co/GpWFr4xlfc
#                                                                              ...
# 1338      RT @outsidemagazine: James Balog's newest documentary hopes to close the political and cultural gap on climate change through the stories o…
# 9678                                                     @AOC @JStein_WaPo This is an important moment, not just for the US. Climate change is global.
# 9788    RT @PaulProvenza: I'm no authority on anything, but...\nIf we weaned ourselves off oil, the entire MidEast dynamic would change. \nSo we'd mi…
# 3903       RT @RobOakeshott1: The National Party declares war on the Gloucester community because they stood up for themselves and won. Remember, the…
# 1207                            @ericbraun556 @ScienceNews It’s because “climate change” is a safer phrase to use. That way you can stay noncommittal.
# Name: text, Length: 100, dtype: object

# %% [markdown]
# **Example of tweet not truncated**

# %%
climate_feed_df['text'].loc[3929]
# Out:
# 'Fighting climate change without nuclear is a fool’s errand. https://t.co/KPSCk6fjsa'

# %% [markdown]
# **Exampe of tweet truncated**

# %%
climate_feed_df['text'].loc[3928]
# Out:
# 'RT @_Oliver_Yates: If only Abbott could fight as hard for the safety of our country from the impacts of climate change, as he is fighting f…'

# %% [markdown]
# Truncated tweet has three horizontal ellipses in it. One can check retweeted_status values and
# use it got the the original tweet text

# %%
climate_feed_df.retweeted_status.loc[3928]
# Out:
# 1.0943594112863928e+18

# %%
retweeted_status_df[retweeted_status_df.id == climate_feed_df.retweeted_status.loc[3928]].text.iloc[0]
# Out:
# 'If only Abbott could fight as hard for the safety of our country from the impacts of climate change, as he is fight… https://t.co/OJlsDeFoNA'

# %% [markdown]
# There is url above tweet. We can use **requests** to get the complete text.

# %% [markdown]
# # Q5(3 points) Perform following activities for creating a new original_tweet_text field in climate_feed_df.
#
# If a record from climate_feed_df has a valid **retweeted_status** value (i.e., it's not null) then search for the original text in retweeted_status_df **text** column.  The text of the tweet in retweeted_status_df will have a url.  This is the url for the original tweet.  On the other hand, if the **truncated** value in climate_feed_df is True, then the record won't have a valid retweet id (it's not a retweet) and the **text** value in climate_feed_df will contain the link to the original tweet.
#
# Search for the original text in retweeted_status_df for tweets with a valid **retweeted_status**.  Store this value in a new column in climate_feed_df called **final_tweet_text**.  I there is not a valid **retweeted_status** in climate_feed_df, then use the value from the **text** column in climate_feed_df.
#
# Finally, create the field **original_tweet_link** in climate_feed_df.  This will be the link to the original tweet which can be obtained from the text field in retweeted_status_df.
#
# Note that we could then use the URLs to retrieve the full tweet text.  This was the requirement of the original assignmnet.  We won't do anything with the URLs except practice extracting them.

# %%
# Unfortunately, with the changes in the way twitter works, we cannot webcrawl or use the api for it. so we will have to use the
# text field only
# Write code here
index = climate_feed_df.index[~climate_feed_df["retweeted_status"].isna() & climate_feed_df["retweeted_status"] > 0]
climate_feed_df["original_tweet_text"] = ""
climate_feed_df["original_tweet_text"] = retweeted_status_df["text"].iloc[index]

# %% [markdown]
# # Q 6(2 points) Remove all the references  of RT and  @user: or @user, and url in climate_feed_df text attribute.

# %%
# write code here
# Remove https
def remove_noise(orig_tweet):
    x = re.sub("https\S+", "", orig_tweet)
    x = re.sub("\\n*", "", x)
    x = re.sub("\@\S+", "", x)
    x = re.sub("RT\S+", "", x)
    # Or a single regex with "https\S+|\\n*|\@\S+|RT\S+"gm, but its the same
    return x
#df["original_tweet_text"] = re.sub("https\S+" ,"",df["original_tweet_text"])
df_valid = climate_feed_df[~climate_feed_df["original_tweet_text"].isna()]
climate_feed_df["original_tweet_text"] = df_valid["original_tweet_text"].apply(remove_noise)
def remove_noise2(orig_tweet):
    x = re.sub("https\S+", "", orig_tweet)
    x = re.sub("\\n*", "", x)
    x = re.sub("\@\S+", "", x)
    x = re.sub("RT", "", x) # For some reason, RT from text field does not get removed with the previous regex
    # Or a single regex with "https\S+|\\n*|\@\S+|RT\S+"gm, but its the same
    return x

df_valid = climate_feed_df[~climate_feed_df["text"].isna()]
climate_feed_df["text"] = df_valid["text"].apply(remove_noise2)
climate_feed_df.head()
# Out:
#                  created_at  \
# 0 2019-02-10 00:17:31+00:00
# 1 2019-02-10 00:17:30+00:00
# 2 2019-02-10 00:17:26+00:00
# 3 2019-02-10 00:17:24+00:00
# 4 2019-02-10 00:17:23+00:00
#
#                                                                                                                                                                                                                                                                                                                                                                                       entities  \
# 0                                {'hashtags': [], 'user_mentions': [{'id_str': '48117116', 'name': 'Steve King', 'screen_name': 'SteveKingIA', 'indices': [1, 13], 'id': 48117116}], 'urls': [{'indices': [117, 140], 'url': 'https://t.co/J1CcrQZkB2', 'display_url': 'twitter.com/i/web/status/1…', 'expanded_url': 'https://twitter.com/i/web/status/1094389867499405313'}], 'symbols': []}
# 1                                                                                                                                                                                                          {'hashtags': [], 'user_mentions': [{'id_str': '16777464', 'name': 'Rob Oakeshott', 'screen_name': 'RobOakeshott1', 'indices': [3, 17], 'id': 16777464}], 'urls': [], 'symbols': []}
# 2  {'hashtags': [], 'user_mentions': [{'id_str': '850130990706151428', 'name': 'Suze Michelini', 'screen_name': 'emilia_suze', 'indices': [3, 15], 'id': 850130990706151428}], 'urls': [{'indices': [105, 128], 'url': 'https://t.co/HWjCJGhQIx', 'display_url': 'twitter.com/LeoDiCaprio/st…', 'expanded_url': 'https://twitter.com/LeoDiCaprio/status/1093998640392220673'}], 'symbols': []}
# 3                                                                                                                                                                                     {'hashtags': [], 'user_mentions': [{'id_str': '753005970318626816', 'name': 'Chad Vigorous', 'screen_name': 'PrettyBadLefty', 'indices': [3, 18], 'id': 753005970318626816}], 'urls': [], 'symbols': []}
# 4                                                                                                                                                                                                 {'hashtags': [], 'user_mentions': [{'id_str': '1634248890', 'name': 'Ken Klippenstein', 'screen_name': 'kenklippenstein', 'indices': [3, 19], 'id': 1634248890}], 'urls': [], 'symbols': []}
#
#    retweeted_status  truncated              user_id  \
# 0               NaN       True             31476142
# 1      1.094332e+18      False            996782298
# 2      1.094385e+18      False             45333453
# 3      1.094379e+18      False  1020067726532829185
# 4      1.094312e+18      False             19889325
#
#                                                                                                                          text  \
# 0                   . says he's unsure about the science of climate change. But you don’t need to be a scientist to take ac…
# 1    The National Party declares war on the Gloucester community because they stood up for themselves and won. Remember, the…
# 2                                     This is the same idiot who thoughtThe southern Alberta chinook was climate change lol.
# 3    Communism is Fascism. Fighting Climate Change will Kill millions. Apparently, you're just allowed to say shit on MSNBC.…
# 4     Unmitigated climate change would literally destroy civilization but doing something about it might increase the defici…
#
#   hashtags     user_mentions  \
# 0                 Steve King
# 1              Rob Oakeshott
# 2             Suze Michelini
# 3              Chad Vigorous
# 4           Ken Klippenstein
#
#                                                                                                      original_tweet_text
# 0                                                                                                                    NaN
# 1  The National Party declares war on the Gloucester community because they stood up for themselves and won. Remember,…
# 2                                This is the same idiot who thoughtThe southern Alberta chinook was climate change lol.
# 3  Communism is Fascism. Fighting Climate Change will Kill millions. Apparently, you're just allowed to say shit on MS…
# 4  Unmitigated climate change would literally destroy civilization but doing something about it might increase the def…

# %% [markdown]
# # Emoji detection
#
# See this example of emoji as unicode characters

# %%
climate_feed_df['text'].loc[3931]
# Out:
# ' Oh my god, CARBON.......😱😱😱 Cue the outrage machine against smartphone. These things are adding to climate change.'

# %% [markdown]
# We can use use regex to capture this emoji
#
# https://apps.timwhitlock.info/emoji/tables/unicode

# %%
emoji_regex = re.compile(r"\U0001F631", re.UNICODE)

# %%
emoji_regex.findall(climate_feed_df['text'].loc[3931])
# Out:
# ['😱', '😱', '😱']

# %% [markdown]
# We can use emoji and/or demoji libraries to make this task easier.  Feel free to use whatever approach you like here.
#
# Here is some documentation about unicode support in python
#
# https://docs.python.org/3/howto/unicode.html

# %%
#! pip install emoji

# %%
#! pip install demoji

# %%
import emoji
import demoji

# %%
x=demoji.findall(climate_feed_df['text'].loc[3931])
x.keys()
# Out:
# dict_keys(['😱'])

# %% [markdown]
# # Q 7(2 points) Create a column  called *emoji*.  This column should contain a list of tuples for emoji detected in *text*. The first element of the tuple is the emoji detected and second is the text describing the emoji.

# %%
# write code here
#emojis = emoji.unicode_codes.get_emoji_unicode_dict("en").values()
df = climate_feed_df.copy()
df["emoji"] = ""
def find_emojis(row):
    return demoji.findall(row.text).keys()
df["emoji"] = df.apply(find_emojis,axis=1)
# Out:
# 54       (😂, 🤣)
# 58          (🌏)
# 62          (🤣)
# 85          (🤣)
# 90          (🤔)
#          ...
# 9842        (🚫)
# 9857        (🌎)
# 9926        (🔹)
# 9957    (❤️, 🌏)
# 9975     (🤦‍♂️)
# Name: emoji, Length: 324, dtype: object

# %%
df[df["emoji"].str.len()>0].sample(100)
# Out:
#                     created_at  \
# 5346 2019-02-09 22:29:09+00:00
# 6991 2019-02-09 21:56:17+00:00
# 2139 2019-02-09 23:36:33+00:00
# 4427 2019-02-09 22:49:48+00:00
# 1045 2019-02-09 23:56:46+00:00
# ...                        ...
# 1714 2019-02-09 23:44:27+00:00
# 2727 2019-02-09 23:26:10+00:00
# 4248 2019-02-09 22:54:03+00:00
# 4770 2019-02-09 22:41:20+00:00
# 5312 2019-02-09 22:29:55+00:00
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              entities  \
# 5346                                                                                                                                                                                                                                                                                                                                                                                              {'hashtags': [], 'user_mentions': [{'id_str': '354162864', 'name': 'Sharmarke Dubow', 'screen_name': 'deardubow', 'indices': [3, 13], 'id': 354162864}], 'urls': [], 'symbols': []}
# 6991                                                                                                                                                                                                                                                                                                                                  {'hashtags': [], 'user_mentions': [], 'urls': [{'indices': [116, 139], 'url': 'https://t.co/6DcsHXCgmm', 'display_url': 'twitter.com/i/web/status/1…', 'expanded_url': 'https://twitter.com/i/web/status/1094354323197308928'}], 'symbols': []}
# 2139                                                                                                                                                                                                                                                                                                                                                                         {'hashtags': [], 'user_mentions': [{'id_str': '835627637049450497', 'name': 'Jordan Sather', 'screen_name': 'Jordan_Sather_', 'indices': [3, 18], 'id': 835627637049450497}], 'urls': [], 'symbols': []}
# 4427                                                                                                                                                                                                                                                                                                                                                                               {'hashtags': [], 'user_mentions': [{'id_str': '1077965512317984768', 'name': 'Kebeh Nayyeh', 'screen_name': 'KNayyeh', 'indices': [3, 11], 'id': 1077965512317984768}], 'urls': [], 'symbols': []}
# 1045                                                                                                                                                                             {'hashtags': [{'indices': [34, 45], 'text': 'uciclimate'}, {'indices': [63, 77], 'text': 'ClimateDenial'}], 'user_mentions': [{'id_str': '18028040', 'name': 'Nicolas Maigret', 'screen_name': 'nico_maigret', 'indices': [3, 16], 'id': 18028040}, {'id_str': '146123790', 'name': 'Peter Gleick', 'screen_name': 'PeterGleick', 'indices': [18, 30], 'id': 146123790}], 'urls': [], 'symbols': []}
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 1714                                                                                                                                                                                                                                                                                                                                                                         {'hashtags': [], 'user_mentions': [{'id_str': '835627637049450497', 'name': 'Jordan Sather', 'screen_name': 'Jordan_Sather_', 'indices': [3, 18], 'id': 835627637049450497}], 'urls': [], 'symbols': []}
# 2727  {'hashtags': [{'indices': [79, 85], 'text': 'Qanon'}], 'user_mentions': [{'id_str': '38194026', 'name': 'DENISE 🌟🌟🌟', 'screen_name': 'dcl1022', 'indices': [0, 8], 'id': 38194026}, {'id_str': '242555999', 'name': 'Sheldon Whitehouse', 'screen_name': 'SenWhitehouse', 'indices': [9, 23], 'id': 242555999}, {'id_str': '4898091', 'name': 'Financial Times', 'screen_name': 'FinancialTimes', 'indices': [24, 39], 'id': 4898091}, {'id_str': '14884486', 'name': 'Brown University', 'screen_name': 'BrownUniversity', 'indices': [40, 56], 'id': 14884486}], 'urls': [...
# 4248                                                                                                                                                                                                                                                                                                                                                                        {'hashtags': [], 'user_mentions': [{'id_str': '1059998580314791937', 'name': 'FROZEN fran 🍏🍎', 'screen_name': 'sun_shine712', 'indices': [3, 16], 'id': 1059998580314791937}], 'urls': [], 'symbols': []}
# 4770         {'hashtags': [], 'user_mentions': [{'id_str': '1052869334509469696', 'name': 'The Short Shorts Historian', 'screen_name': 'TeslaQ3', 'indices': [0, 8], 'id': 1052869334509469696}, {'id_str': '258612274', 'name': 'Mark B. Spiegel', 'screen_name': 'markbspiegel', 'indices': [9, 22], 'id': 258612274}], 'urls': [{'indices': [67, 90], 'url': 'https://t.co/J91jvgNXrn', 'display_url': 'latimes.com/opinion/op-ed/…', 'expanded_url': 'https://www.latimes.com/opinion/op-ed/la-oe-bloomberg-climate-change-risk-disclosure-20190208-story.html'}], 'symbols': []}
# 5312                                                                                                                                                                                                                                                                                                                                                                                                     {'hashtags': [], 'user_mentions': [{'id_str': '783792992', 'name': 'Ilhan Omar', 'screen_name': 'IlhanMN', 'indices': [3, 11], 'id': 783792992}], 'urls': [], 'symbols': []}
#
#       retweeted_status  truncated              user_id  \
# 5346      1.094022e+18      False   917474639684571136
# 6991               NaN       True  1042086259072659457
# 2139      1.094379e+18      False            357526182
# 4427      1.093535e+18      False             39401495
# 1045      1.094365e+18      False              7703052
# ...                ...        ...                  ...
# 1714      1.094379e+18      False   954090946874040321
# 2727               NaN       True           1901908940
# 4248      1.094120e+18      False   965038974388658176
# 4770               NaN      False           1332384978
# 5312      1.092994e+18      False            129672862
#
#                                                                                                                                text  \
# 5346       Promises made are delivered. 🚨Renters’ Advisory Committee🚨Permanent resident vote 🗳🚨Affordable housing policies🚨Welcomi…
# 6991             "Guys I'm not a socialist, but I believe in literally every core principle of socialism." 🤣1. Healthcare isn't a…
# 2139           🤣🤣🤣Quite the crock of shit, here!Don’t even try to sell me your Geoengineering nonsense based off ridiculous climat…
# 4427                                            👏you👏are👏not👏serious👏about👏climate👏change👏if👏nuclear👏power👏is👏not👏in👏your👏proposal👏
# 1045                 at #uciclimate 🌪🙈 &gt;Panel on #ClimateDenial "Humans are responsible for 110% of climate change, because we'…
# ...                                                                                                                             ...
# 1714           🤣🤣🤣Quite the crock of shit, here!Don’t even try to sell me your Geoengineering nonsense based off ridiculous climat…
# 2727                                                                    Sure can, the hoax is #Qanon and the jerkoff is Denise 😏C…
# 4248       SCHUMER: CLIMATE CHANGE IS GOING TO EVOKE HUGE CHANGES IN USA NEXT 10 to 40 YRS👉The climate change can be interpreted b…
# 4770                                                                                     Dint PGE recently filed for bankruptcy?! 🤔
# 5312    Things Trump declined to mention in his speech:🚫 Climate Change 🚫 His shutdown: the longest in U.S. history🚫 Federal worke…
#
#                       hashtags  \
# 5346
# 6991
# 2139
# 4427
# 1045  uciclimate,ClimateDenial
# ...                        ...
# 1714
# 2727                     Qanon
# 4248
# 4770
# 5312
#
#                                                        user_mentions  \
# 5346                                                 Sharmarke Dubow
# 6991
# 2139                                                   Jordan Sather
# 4427                                                    Kebeh Nayyeh
# 1045                                    Nicolas Maigret,Peter Gleick
# ...                                                              ...
# 1714                                                   Jordan Sather
# 2727  DENISE 🌟🌟🌟,Sheldon Whitehouse,Financial Times,Brown University
# 4248                                                  FROZEN fran 🍏🍎
# 4770                      The Short Shorts Historian,Mark B. Spiegel
# 5312                                                      Ilhan Omar
#
#                                                                                                       original_tweet_text  \
# 5346    Promises made are delivered. 🚨Renters’ Advisory Committee🚨Permanent resident vote 🗳🚨Affordable housing policies…
# 6991                                                                                                                  NaN
# 2139    🤣🤣🤣Quite the crock of shit, here!Don’t even try to sell me your Geoengineering nonsense based off ridiculous cl…
# 4427                                  👏you👏are👏not👏serious👏about👏climate👏change👏if👏nuclear👏power👏is👏not👏in👏your👏proposal👏
# 1045            at #uciclimate 🌪🙈 &gt;Panel on #ClimateDenial "Humans are responsible for 110% of climate change, becau…
# ...                                                                                                                   ...
# 1714    🤣🤣🤣Quite the crock of shit, here!Don’t even try to sell me your Geoengineering nonsense based off ridiculous cl…
# 2727                                                                                                                  NaN
# 4248  SCHUMER: CLIMATE CHANGE IS GOING TO EVOKE HUGE CHANGES IN USA NEXT 10 to 40 YRS👉The climate change can be interpr…
# 4770                                                                                                                  NaN
# 5312    Things Trump declined to mention in his speech:🚫 Climate Change 🚫 His shutdown: the longest in U.S. history🚫 Fe…
#
#        emoji
# 5346  (🚨, 🗳)
# 6991     (🤣)
# 2139     (🤣)
# 4427     (👏)
# 1045  (🌪, 🙈)
# ...      ...
# 1714     (🤣)
# 2727     (😏)
# 4248     (👉)
# 4770     (🤔)
# 5312     (🚫)
#
# [100 rows x 10 columns]
