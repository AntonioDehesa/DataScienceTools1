# %% [markdown]
# # Hw 1. Please complete the following activity and submit the notebook in LMS (learning management system). This homework is due by the end of week 3, to allow time for selecting your team and topic of the final project.

# %% [markdown]
# # Q1(.5 point) Why we need Python virtual environments?
#
# Please write no more than 3 lines.

# %% [markdown]
# *write you response here*
# A Python virtual environment allows us to have completely separate environments for our projects in the same computer.
# This is helpful in a multi-project environment, specially when each project has different requirements, such as library a needing version 1.1 in project A, and in project B library a must be version 1.5.

# %% [markdown]
# # Q2(.5 point) Sort the following list in place alphabetically using last three characters.

# %%
continentsL = ['Europe', 'Africa', 'America', 'Antarctica', 'Asia', 'Australia']
# Write you code in the next line
continentsL.sort(key=lambda x: x[-3:])
continentsL
# Out:
# ['Africa', 'America', 'Antarctica', 'Australia', 'Europe', 'Asia']

# %% [markdown]
# # Q3(1= .5+.5 points) We want to compare random integer generation time in numpy and random module of "plain" python. Generate 100 random integers in the range 1 to 10 including 1 and 10. Write jupyter notebook line magic to compare execution time of random integer generation in the following cells (look for the cells having the comment *write line magic*).  Line magic must execute the given statement  10 times in a loop and repeat the process 5 times.
#
#
#  Hints:
#
#  - Note that numpy.random has randint function and random has random.randint function.
#  - Press shift+tab after typing above function or search their documentation to understand their parameters.
#  - use ? on magic command timeit for further documentation. see how to use **-n and -r options**.

# %%
import random
num_sample = 100
low = 1
high = 10

# %%
# write line magic for random module in the next line
# %time for _ in range(num_sample): random.randint(low, high)
# Out:
# CPU times: user 49 µs, sys: 24 µs, total: 73 µs
# Wall time: 76.1 µs

# %%
import numpy as np

# %%
# write line magic for numpy randint in the next line
# %time for _ in range(num_sample): np.random.randint(low, high)
# Out:
# CPU times: user 1.32 ms, sys: 1.06 ms, total: 2.39 ms
# Wall time: 6.99 ms

# %% [markdown]
# <font size = "6"> To start working toward final project, complete the following questions by writing markdown in the same cell in next line. Each question in worth .5 point. </font>
#
# In tools 1 course, __*we are concerned with data cleaning, feature engineering and exploratory analysis. Make sure your selected final project allows for lots of data cleaning, transformation and engineering opportunity.*__
#
# Go over project and presentation rubric in course webpage to better understand the requirement for the project.  We will evaluate the answer to see if it meets the final project requirements.
#
#
#
# <font color = "red" size = "5">If you are working in a team, we'll read only one team member notebook for the following questions. Please make sure you have identical answers for following questions.  </font>
#
# <font color ="red"> To edit a markdown cell you need to double click in the cell</font>

# %% [markdown]
# # Q4 List your team members in bullet format. (No more than 3 members).
# Note that
#
# - **Each member** has to present a portion of the project in the final presentation.
#
# -  Final report must list the contribution of each member.

# %% [markdown]
# *write you response here*
# * Edmond Balika
# * Ignacio Luque
# * Antonio Dehesa
# * Nii Kwatel Quartey

# %% [markdown]
# # Q5  What  problem you are trying to solve?

# %% [markdown]
# Discovering the relationship between sex, ethnicity, and other characteristics, with the wage disparity.
# Undertanding this relationship would allow us to, eventually, with the adequate resources, reduce or even solve the disparity of wages.

# %% [markdown]
# # Q6 Describe the attributes of examples in the dataset. If you are planning to collect the data (webscrapping, web API etc.), list the timeline to finish the data collection.

# %% [markdown]
# The Salary Survey Responses have a total of 17 attributes, namely:
# 1.	Age Range
# 2.	Industry the employees works in
# 3.	Job Title
# 4.	Job title context
# 5.	Annual Salary
# 6.	Additional Compensation
# 7.	Currency
# 8.	Alternative Currency
# 9.	Income Context
# 10.	Country
# 11.	US State (if Country is USA)
# 12.	City
# 13.	Overall Experience (Year range)
# 14.	Experience in Field Currently Employed (Year range)
# 15.	Education Level
# 16.	Gender
# 17.	Race
# Six (6) out of the 17 attributes are free-form text entry, which provide opportunity for lots of data cleaning to be done.
#
# Two (2) of the 17 attributes are numeric (Annual Salary and Additional Compensation) and the remaining 15 attributes may be deemed as categorical.
#
# The dataset we intend to use is freely available and accessible at https://docs.google.com/spreadsheets/d/1IPS5dBSGtwYVbjsfbaMCYIWnOuRmJcbequohNxCyGVw/edit?resourcekey#gid=1625408792

# %% [markdown]
# # Q7 Give example of records (sample points). Explain why this is a noisy data set (highlight  portion of record attributes you think are noisy).

# %% [markdown]
# Below is an image of example records:
#
# ![image.png](attachment:image.png)
# As shown in the sample data above, we can see that the column, “What country do you work in?” has inconsistent entries. In some cases, the United States is captured as USA, US, U.S.A us, United Statew, U.S. United States among others.
# Another Noisy dataset can be found in the “What is your race?” column, where a person identifies as Asian or Asian American, Black or African American, White at the same time.

# %% [markdown]
# # Q8 What kind of  feature engineering opportunity you see.
#
# We'll cover feature engineering but here are some examples to get an idea of feature engineering.
# - Do you need to extract a number, year, or a word in column (attribute of a record).
#     + Perhaps extracting Miss, Mr., Dr. is more important than actual name?
#     + Maybe year or time is embbedded in the text desciption and it is important for analysis.
# - If a column has numerical values do you see a potential for using these values or a transformation of these values like square, log etc?

# %% [markdown]
# * Data cleaning: Not every observation in the dataset is complete, and we would like to focus on observations that are within 3 standard deviations, so every observation that is not complete, or is outside the 3 standard deviations will be deleted. Some observations may also include a different sex other that binary options, which would cause issues during clustering or predictions, so those will be cleaned as well
# * Data validation: Not every observation includes the wage in the same currency, which would affect any prediction, clustering, or regression performed on the data, so we need to ensure there is only one currency
# * Data transformation: As previously mentioned, not every observation includes the wages in the same currency, so to avoid issues, we will use the USD as the standard, and every other currency will be transformed to USD with the current exchange rate
# * PCA: As the dataset includes multiple characteristics for each observation, we would need to reduce the dimensionality with PCA to focus on the most relevant features
# * Clustering or modelling: With the reduced dimensionality, we can perform clustering techniques, regression, or prediction models to better understand the relationship between the features and the wages
